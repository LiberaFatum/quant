# %%
import numpy as np
import pandas as pd

# %%
predefined_data = [10, 20, 30, 40, 50]
s = pd.Series(predefined_data)  #panda series je jednodozmerny array, akorat s indexem

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(f"Prumer: {s.mean()}")
print(f"Median: {s.median()}")
print(f"Velkost ndarraye: {s.shape}")
# Out:
# Prumer: 30.0
# Median: 30.0
# Velkost ndarraye: (5,)
